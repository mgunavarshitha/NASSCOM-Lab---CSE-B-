# %% [markdown]
# Basic Try-Except Block

# %%
try:
    x = int(input("Enter a number: "))
    print("You entered:", x)
except ValueError:
    print("That was not a valid number!")
# Out:
# Enter a number: 12
# You entered: 12

# %%
try:
    num = int(input("Enter a number to divide 100: "))
    result = 100 / num
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Invalid input! Not a number.")
else:
    print("Result is:", result)
finally:
    print("Execution complete. This block always runs.")
# Out:
# Enter a number to divide 100: 8481
# Result is: 0.011791062374719963
# Execution complete. This block always runs.

# %%
try:
    a = int("ten")
    b = 10 / 0
except (ValueError, ZeroDivisionError) as e:
    print("An error occurred:", e)
# Out:
# An error occurred: invalid literal for int() with base 10: 'ten'

# %%
def check_age(age):
    if age < 0:
        raise ValueError("Age cannot be negative!")
    else:
        print("Age is valid.")

try:
    check_age(-5)
except ValueError as e:
    print("Caught an exception:", e)
# Out:
# Caught an exception: Age cannot be negative!

# %%
def divide(a, b):
    print(f"Dividing {a} by {b}")
    return a / b

print(divide(10, 2))
# Out:
# Dividing 10 by 2
# 5.0

# %%
import traceback

try:
    result = 10 / 0
except Exception as e:
    print("Something went wrong.")
    traceback.print_exc()
# Out:
# Something went wrong.
# Traceback (most recent call last):
#   File "/tmp/ipykernel_401/142134494.py", line 4, in <cell line: 0>
#     result = 10 / 0
#              ~~~^~~
# ZeroDivisionError: division by zero

# %%
def calculate_total(price, quantity):
    return price * quantity
print(calculate_total(90, 2))
# Out:
# 180

# %% [markdown]
# Libraries

# %%
import os
print("Current Directory:", os.getcwd())
print("Files and Folders:", os.listdir())
os.mkdir("demo_folder")
os.rename("demo_folder", "renamed_folder")
os.rmdir("renamed_folder")
# Out:
# Current Directory: /content
# Files and Folders: ['.config', 'sample_data']

# %%
from datetime import datetime, date, timedelta
now = datetime.now()
print("Now:", now)
today = date.today()
print("Today's Date:", today)
dob = date(2000, 1, 1)
print("DOB:", dob)
yesterday = today - timedelta(days=1)
tomorrow = today + timedelta(days=1)
print("Yesterday:", yesterday)
print("Tomorrow:", tomorrow)
formatted = now.strftime("%d-%m-%Y %H:%M:%S")
print("Formatted DateTime:", formatted)
# Out:
# Now: 2026-08-18 13:37:30.791781
# Today's Date: 2026-08-18
# DOB: 2000-01-01
# Yesterday: 2026-08-17
# Tomorrow: 2026-08-19
# Formatted DateTime: 18-08-2026 13:37:30

# %%
import random
print("Random Int:", random.randint(1, 100))
print("Random Float:", random.random())
colors = ['red', 'green', 'blue']
print("Random Color:", random.choice(colors))
random.shuffle(colors)
print("Shuffled List:", colors)
print("Sample:", random.sample(range(1, 50), 5))
# Out:
# Random Int: 54
# Random Float: 0.7655152699671701
# Random Color: blue
# Shuffled List: ['green', 'blue', 'red']
# Sample: [5, 35, 49, 37, 7]

# %%
from collections import Counter
fruits = ['apple', 'banana', 'apple', 'orange', 'banana', 'apple']
count = Counter(fruits)
print("Fruit Count:", count)
# Out:
# Fruit Count: Counter({'apple': 3, 'banana': 2, 'orange': 1})

# %%
from collections import defaultdict
marks = defaultdict(lambda: 0 )
marks['math'] = 90
marks['science'] = 80
print("English Marks (not set):", marks['English'])
# Out:
# English Marks (not set): 0

# %%
from collections import namedtuple
Point = namedtuple('Point', 'x y')
p1 = Point(10,20)
print("Point:", p1)
print("x:", p1.x, "y:", p1.y)
# Out:
# Point: Point(x=10, y=20)
# x: 10 y: 20

# %%
from collections import deque
dq = deque([1,2,3])
dq.append(4)
dq.appendleft(0)
dq.pop()
dq.popleft()
print("Deque after operations:", dq)
# Out:
# Deque after operations: deque([1, 2, 3])
